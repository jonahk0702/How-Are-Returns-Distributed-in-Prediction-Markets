# %%
import os
from py_clob_client.client import ClobClient
from py_clob_client.constants import POLYGON

# Set your private key and host
private_key = os.getenv("YOUR_PRIVATE_KEY_ENV_VARIABLE")
host = "https://clob.polymarket.com"
chain_id = POLYGON  # Polygon Mainnet chain ID

# Initialize the client
client = ClobClient(host, key=private_key, chain_id=chain_id)

# %%
markets = client.get_markets()
for market in markets:
    print(market)
    #print(f"Market ID: {market['id']}, Question: {market['question']}")
# Out:
# data
# next_cursor
# limit
# count

# %%
import requests
import json

url = "https://damp-solitary-dust.matic.quiknode.pro/532d4e0c5f835b4a1b25ef1dd1fc1e8849899660/"

payload = json.dumps({
  "method": "eth_blockNumber",
  "params": [],
  "id": 1,
  "jsonrpc": "2.0"
})

headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"jsonrpc":"2.0","id":1,"result":"0x3d994ba"}
